# %% [markdown]
# # Nhập xuất dữ liệu và String
# ## Cách nhập xuất dữ liệu

# %% [markdown]
# ### Xuất dữ liệu ra màn hình
# Để in các nội dung mà chúng ta mong muốn ra màn hình, ta sử dụng lệnh print()

# %%
# Ví dụ: In ra nội dung "python is very easy"

# %% [markdown]
# ### Các cách custom với lệnh print

# %% [markdown]
# Để in một nội dung kèm theo giá trị của biến, ta có các cách sau:

# %%
food_1 = "chocolate"
food_2 = "sandwich"

# %%
# In trực tiếp

# %%
# In bằng cách ghép các nội dung với nhau

# %%
# Sử dụng String Format

# %%
# Sử dụng nhiều lệnh print

# %% [markdown]
# ### Nhập dữ liệu
# Để nhập dữ liệu vào chương trình python, chúng ta sử dụng hàm input()

# %%
name = input("Please input your name: ")
print(name)
print(type(name))
# Out:
# Please input your name:  Bui Trong Tri
# Bui Trong Tri
# <class 'str'>

# %%
month = int(input("Please input current month: ")) # type casting ( int(), float(), bool(), str() )
print(month)
print(type(month))
# Out:
# Please input current month:  5
# 5
# <class 'int'>

# %% [markdown]
# #### Thực hành: Viết chương trình nhập vào chiều dài và chiều rộng của hình chữ nhật, sau đó in ra chu vi và diện tích của hình chữ nhật đó

# %% [markdown]
# ![image.png](attachment:69d50bc8-6af2-44d5-8981-9f3688707a7c.png)

# %%
# Nhập các kích thước của hình chữ nhật
a = float(input("Nhập kích thước chiều dài: "))
b = float(input("Nhập kích thước chiều rộng: "))
# Out:
# Nhập kích thước chiều dài:  2.5
# Nhập kích thước chiều rộng:  3.4

# %%
# Tính toán chu vi, diện tích
P = (a + b) * 2
S = a * b

# %%
# In kết quả ra màn hình bằng 3 cách
print(f"Chu vi của hình chữ nhật có chiều dài {a} và chiều rộng {b}: {P}")
print(f"Diện tích của hình chữ nhật có chiều dài {a} và chiều rộng {b}: {S}")
# Out:
# Chu vi của hình chữ nhật có chiều dài 2.5 và chiều rộng 3.4: 11.8
# Diện tích của hình chữ nhật có chiều dài 2.5 và chiều rộng 3.4: 8.5

# %% [markdown]
# #### Thực hành: Viết chương trình nhập vào số đo cạnh và mã màu của tam giác đều, sau đó sử dụng turtle để vẽ ra hình tam giác có số đo và màu tương ứng

# %% [markdown]
# ## Cú pháp import

# %% [markdown]
# Để sử dụng một module từ bên ngoài, chúng ta sẽ sử dụng từ khóa import. Sau đây là ví dụ về một số cách import phổ biến.

# %% [markdown]
# ### Random một giá trị ngẫu nhiên

# %% [markdown]
# ### Thực hiện các phép toán số học

# %%
# import toàn bộ module

# %%
# import một phần trong module

# %% [markdown]
# ## Xử lý String trong python

# %% [markdown]
# ### String là gì?
# String là một chuỗi gồm các ký tự Unicode

# %% [markdown]
# ### Khởi tạo một string

# %%
# one-line string

# %%
# multi-line string

# %% [markdown]
# ### Các thao tác phổ biến với string

# %%
# Kiểm tra độ dài string

# %%
# Truy xuất ký tự bằng cơ chế indexing và reverse indexing

# %% [markdown]
# #### Thực hành: Viết chương trình nhập vào một chuỗi bất kỳ, sau đó in ra ký tự đầu tiên và ký tự cuối cùng của chuỗi đó.

# %%
# Cắt string theo index

# %%
# Ghép chuỗi và lặp chuỗi

# %% [markdown]
# #### Thực hành: Xử lý và in ra các thông tin tương ứng trong chuỗi

# %% [markdown]
# ### Các hàm thông dụng khi xử lý string

# %%
# len

# %%
# count

# %%
# upper, lower

# %%
# lstrip, rstrip, strip

# %%
# split
